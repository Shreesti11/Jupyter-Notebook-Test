# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

url = "https://drive.google.com/uc?id=16DeG8mBHOMjYZYsuoc1r_7ivwMZf6mOA"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                     0       1         1          1   40       1       0
# 1                     0       0         0          0   25       1       0
# 2                     0       1         1          1   28       0       0
# 3                     0       1         0          1   27       0       0
# 4                     0       1         1          1   24       0       0
#
#    Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0         0             0       0  ...              1            0        5
# 1         0             1       0  ...              0            1        3
# 2         0             0       1  ...              1            1        5
# 3         0             1       1  ...              1            0        2
# 4         0             1       1  ...              1            0        2
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# ...

# %%
# Age
plt.subplot(2, 2, 1)
sns.histplot(df['Age'], bins=20, kde=False, color='skyblue')
plt.title("Distribution of Age")

plt.tight_layout()
plt.show()

# %%
# BMI
plt.subplot(2, 2, 2)
sns.histplot(df['BMI'], bins=20, kde=True, color='orange')
plt.title("Distribution of BMI")

plt.tight_layout()
plt.show()

# %%
# Mental Health Days
plt.subplot(2, 2, 3)
sns.histplot(df['MentHlth'], bins=30, kde=False, color='green')
plt.title("Distribution of Mental Health Days (Past 30 days)")

plt.tight_layout()
plt.show()

# %%
# Physical Health Days
plt.subplot(2, 2, 4)
sns.histplot(df['PhysHlth'], bins=30, kde=False, color='red')
plt.title("Distribution of Physical Health Days (Past 30 days)")

plt.tight_layout()
plt.show()

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['BMI'])
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\4107119561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'])
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
sns.distplot(df['MentHlth'])
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\2350003625.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MentHlth'])
# <Axes: xlabel='MentHlth', ylabel='Density'>

# %%
sns.distplot(df['PhysHlth'])
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\3942459401.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PhysHlth'])
# <Axes: xlabel='PhysHlth', ylabel='Density'>

# %%
# High Blood Pressure
plt.subplot(1, 2, 1)
sns.countplot(x='HighBP', data=df, palette='Set2')
plt.title("Prevalence of High Blood Pressure")
plt.xticks([0, 1], ['No', 'Yes'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\565361242.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HighBP', data=df, palette='Set2')

# %%
# High Cholesterol
plt.subplot(1, 2, 2)
sns.countplot(x='HighChol', data=df, palette='Set3')
plt.title("Prevalence of High Cholesterol")
plt.xticks([0, 1], ['No', 'Yes'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\2046167695.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HighChol', data=df, palette='Set3')

# %%
# --- Bar Chart ---
plt.figure(figsize=(6,4))
sns.countplot(x='HeartDiseaseorAttack', data=df, palette='coolwarm')
plt.title("Distribution of Heart Disease Cases")
plt.xticks([0,1], ['No Heart Disease', 'Heart Disease'])
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_19092\3569966452.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HeartDiseaseorAttack', data=df, palette='coolwarm')

# %%
# --- Pie Chart ---
plt.figure(figsize=(6,6))
df['HeartDiseaseorAttack'].value_counts().plot.pie(
    labels=['No Heart Disease', 'Heart Disease'],
    autopct='%1.1f%%',
    colors=['lightgreen','salmon'],
    startangle=90,
    explode=[0, 0.1]  # highlight heart disease slice
)
plt.title("Heart Disease Prevalence")
plt.ylabel("")
plt.show()
